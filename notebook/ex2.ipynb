# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# pip install matplotlib

# %%
csv_file_path = r"E:\ML_project_2\adult_census_income_prediction\adult_census_income_dataset.csv"
import os
df = pd.read_csv(csv_file_path)
df.head()

# %%
import os
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.dtypes.index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
# remove column from dataframe
df.drop(['Unnamed: 0'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6804\302978778.py in <module>
#       1 # remove column from dataframe
# ----> 2 df.drop(['Unnamed: 0'], axis=1, inplace=True)
#
# e:\ML_project_2\adult_census_income_prediction\venv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# e:\ML_project_2\adult_census_income_prediction\venv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.dtypes.index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
data_type = list(map(lambda x: x.name, df.dtypes))

# %%
column = df.columns

# %%
schema_dict = dict(zip(column, data_type))
schema_dict
# Out:
# {'age': 'object',
#  'workclass': 'object',
#  'fnlwgt': 'float64',
#  'education': 'object',
#  'education-num': 'float64',
#  'marital-status': 'object',
#  'occupation': 'object',
#  'relationship': 'object',
#  'race': 'object',
#  'sex': 'object',
#  'capital-gain': 'float64',
#  'capital-loss': 'float64',
#  'hours-per-week': 'float64',
#  'native-country': 'object',
#  'salary': 'object'}

# %%
df
# Out:
#       age          workclass    fnlwgt      education  education-num  \
# 0      34            Private  136997.0        HS-grad            9.0
# 1      24            Private  403107.0      Preschool            1.0
# 2      80            Private   22406.0      Bachelors           13.0
# 3      45            Private   59380.0      Bachelors           13.0
# 4      66            Private   22502.0        7th-8th            4.0
# ...    ..                ...       ...            ...            ...
# 39069  23            Private  182494.0        7th-8th            4.0
# 39070  81            Private   55314.0      Bachelors           13.0
# 39071  43   Self-emp-not-inc  193459.0   Some-college           10.0
# 39072  49            Private  268234.0        7th-8th            4.0
# 39073  26            Private  179864.0        HS-grad            9.0
#
#             marital-status          occupation     relationship  \
# 0                 Divorced        Adm-clerical        Unmarried
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df[df == ' ?'].count()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# country            583
# salary               0
# dtype: int64

# %%
df[df == ' ?']=np.nan

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# country            583
# salary               0
# dtype: int64

# %%
for col in ['workclass', 'occupation','country']:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df.to_csv(r"E:\ML_project_2\adult_census_income_prediction\adult_census_income_dataset.csv", index=False)

# %% [markdown]
# E:\ML_project_2\adult_census_income_prediction\requirements.txt

# %%
schema_file_path = r"E:\ML_project_2\adult_census_income_prediction\config\schema.yaml"

# %%
import yaml
from census_income.util.util import read_yaml_file
from census_income.exception import Acip_Exception
import os,sys
import numpy as np
import dill
import pandas as pd
from census_income.constant import *

# %%
dataset_schema = read_yaml_file(schema_file_path)

# %%
schema = dataset_schema[DATASET_SCHEMA_COLUMNS_KEY]

# %%
dataframe = pd.read_csv(csv_file_path)

# %%
for column in dataframe.columns:
    if column in list(schema.keys()):
        dataframe[column] = dataframe[column].astype(schema[column])

# %%
dataframe[column]
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32556     <=50K
# 32557      >50K
# 32558     <=50K
# 32559     <=50K
# 32560      >50K
# Name: salary, Length: 32561, dtype: object

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
from census_income.exception import Acip_Exception
from census_income.logger import logging
from census_income.entity.config_entity import DataTransformationConfig 
from census_income.entity.artifact_entity import DataIngestionArtifact,\
DataValidationArtifact,DataTransformationArtifact
import sys,os
import numpy as np
from sklearn.base import BaseEstimator,TransformerMixin
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from census_income.component import data_transformation
import pandas as pd
from census_income.constant import *
from census_income.util.util import read_yaml_file,save_object,save_numpy_array_data,load_data

# %%
train_df = df.drop(['salary'], axis=1)

# %%
target_df = df['salary']

# %%
train_df.head(1)
# Out:
#    age   workclass  fnlwgt   education  education-num  marital-status  \
# 0   39   State-gov   77516   Bachelors             13   Never-married
#
#       occupation    relationship    race    sex  capital-gain  capital-loss  \
# 0   Adm-clerical   Not-in-family   White   Male          2174             0
#
#    hours-per-week         country
# 0              40   United-States

# %%
target_df.head(1)
# Out:
# 0     <=50K
# Name: salary, dtype: object

# %%
train_arr = np.c_[train_df, np.array(target_df)]

# %%
train_arr.shape
# Out:
# (32561, 15)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df[df == ' Private'].count()
# Out:
# age                   0
# workclass         24532
# fnlwgt                0
# education             0
# education-num         0
# marital-status        0
# occupation            0
# relationship          0
# race                  0
# sex                   0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# country               0
# salary                0
# dtype: int64

# %%
df[df == ' ?'].count()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df['workclass'].dtypes
# Out:
# dtype('O')

# %%
for feature in df.columns:
    print(feature,'==>', df[feature].dtype)
# Out:
# age ==> int64
# workclass ==> object
# fnlwgt ==> int64
# education ==> object
# education-num ==> int64
# marital-status ==> object
# occupation ==> object
# relationship ==> object
# race ==> object
# sex ==> object
# capital-gain ==> int64
# capital-loss ==> int64
# hours-per-week ==> int64
# country ==> object
# salary ==> object

# %%
df.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
figure = plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True,cmap=plt.cm.cool)
plt.tight_layout()
plt.xlabel('Corr')
plt.show()

# %%
# !pip install seaborn
# Out:
# ...
#      ------------------------------------ 292.8/292.8 kB 361.8 kB/s eta 0:00:00
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
for feature in df.columns:
    if df[feature].dtype == object:
        df.drop(feature, axis=1, inplace=True)

# %%
df.head()
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
csv_file_path = r"E:\ML_project_2\adult_census_income_prediction\adult_census_income_dataset.csv"
import os
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
num_features = []
cat_features = []
for feature in df.columns:
    if df[feature].dtype == object:
        cat_features.append(feature)
    else:
        num_features.append(feature)

# %%
num_features
# Out:
# ['age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
cat_features
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'country',
#  'salary']

# %%
cat_features.remove('workclass')

# %%
cat_features
# Out:
# ['education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'country',
#  'salary']

# %%
cat_features.remove('salary')

# %%
cat_features
# Out:
# ['education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'country']

# %%
for feature in cat_features:
    df.drop(feature, axis=1, inplace=True)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          State-gov   77516             13          2174             0
# 1   50   Self-emp-not-inc   83311             13             0             0
# 2   38            Private  215646              9             0             0
# 3   53            Private  234721              7             0             0
# 4   28            Private  338409             13             0             0
#
#    hours-per-week  salary
# 0              40   <=50K
# 1              13   <=50K
# 2              40   <=50K
# 3              40   <=50K
# 4              40   <=50K

# %%
df.to_csv(r"E:\ML_project_2\adult_census_income_prediction\demo.csv", index=False)

# %%
df=pd.read_csv(r"E:\ML_project_2\adult_census_income_prediction\demo.csv")

# %%
df['salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
for feature in df.columns:
    if df[feature].dtype == object:
        df[feature] = df[feature].astype('category')
        df[feature] = df[feature].cat.codes

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          6   77516             13          2174             0
# 1   50          5   83311             13             0             0
# 2   38          3  215646              9             0             0
# 3   53          3  234721              7             0             0
# 4   28          3  338409             13             0             0
#
#    hours-per-week  salary
# 0              40       0
# 1              13       0
# 2              40       0
# 3              40       0
# 4              40       0

# %%
df['workclass'].unique()
# Out:
# array([6, 5, 3, 0, 1, 4, 7, 2], dtype=int8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int8
#  2   fnlwgt          32561 non-null  int64
#  3   education-num   32561 non-null  int64
#  4   capital-gain    32561 non-null  int64
#  5   capital-loss    32561 non-null  int64
#  6   hours-per-week  32561 non-null  int64
#  7   salary          32561 non-null  int8
# dtypes: int64(6), int8(2)
# memory usage: 1.6 MB

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("E:\\ML_project_2\\adult_census_income_prediction\\demo.csv")

# %%
df.head ()
# Out:
#    age          workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          State-gov   77516             13          2174             0
# 1   50   Self-emp-not-inc   83311             13             0             0
# 2   38            Private  215646              9             0             0
# 3   53            Private  234721              7             0             0
# 4   28            Private  338409             13             0             0
#
#    hours-per-week  salary
# 0              40   <=50K
# 1              13   <=50K
# 2              40   <=50K
# 3              40   <=50K
# 4              40   <=50K

# %%
print(df[df == ' Private'].count(),"====>", df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education-num   32561 non-null  int64
#  4   capital-gain    32561 non-null  int64
#  5   capital-loss    32561 non-null  int64
#  6   hours-per-week  32561 non-null  int64
#  7   salary          32561 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 2.0+ MB
# age                   0
# workclass         24532
# fnlwgt                0
# education-num         0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# salary                0
# dtype: int64 ====> None

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          State-gov   77516             13          2174             0
# 1   50   Self-emp-not-inc   83311             13             0             0
# 2   38            Private  215646              9             0             0
# 3   53            Private  234721              7             0             0
# 4   28            Private  338409             13             0             0
#
#    hours-per-week  salary
# 0              40   <=50K
# 1              13   <=50K
# 2              40   <=50K
# 3              40   <=50K
# 4              40   <=50K

# %%
df.drop(['workclass'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
df.to_csv(r"E:\ML_project_2\adult_census_income_prediction\demo1.csv", index=False)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          State-gov   77516             13          2174             0
# 1   50   Self-emp-not-inc   83311             13             0             0
# 2   38            Private  215646              9             0             0
# 3   53            Private  234721              7             0             0
# 4   28            Private  338409             13             0             0
#
#    hours-per-week  salary
# 0              40   <=50K
# 1              13   <=50K
# 2              40   <=50K
# 3              40   <=50K
# 4              40   <=50K

# %%
df.shape
# Out:
# (32561, 8)

# %%
df['salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df['salary']=df['salary'].map({' <=50K': 0, ' >50K': 1})

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          State-gov   77516             13          2174             0
# 1   50   Self-emp-not-inc   83311             13             0             0
# 2   38            Private  215646              9             0             0
# 3   53            Private  234721              7             0             0
# 4   28            Private  338409             13             0             0
#
#    hours-per-week  salary
# 0              40       0
# 1              13       0
# 2              40       0
# 3              40       0
# 4              40       0

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df['workclass']=df['workclass'].map({' Private': 0, ' Self-emp-not-inc': 1, ' Self-emp-inc': 2, ' Federal-gov': 3, ' Local-gov': 4, ' State-gov': 5, ' Without-pay': 6, ' Never-worked': 7})

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education-num  capital-gain  capital-loss  \
# 0   39          5   77516             13          2174             0
# 1   50          1   83311             13             0             0
# 2   38          0  215646              9             0             0
# 3   53          0  234721              7             0             0
# 4   28          0  338409             13             0             0
#
#    hours-per-week  salary
# 0              40       0
# 1              13       0
# 2              40       0
# 3              40       0
# 4              40       0

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int64
#  2   fnlwgt          32561 non-null  int64
#  3   education-num   32561 non-null  int64
#  4   capital-gain    32561 non-null  int64
#  5   capital-loss    32561 non-null  int64
#  6   hours-per-week  32561 non-null  int64
#  7   salary          32561 non-null  int64
# dtypes: int64(8)
# memory usage: 2.0 MB

# %%
df.to_csv(r"E:\ML_project_2\adult_census_income_prediction\demo3.csv", index=False)
